# %%
# !sf
# Out:
# 2025-10-24 17:00:46 :: sf :: sf.go:466: [FATAL] expecting one or more file or directory arguments (or '-' to scan stdin)

# %%
# !sf -sig deluxe.sig README.md
# Out:
# ---
# siegfried   : 1.11.2
# scandate    : 2025-10-24T17:00:46Z
# signature   : deluxe.sig
# created     : 2025-03-01T15:28:39+11:00
# identifiers :
#   - name    : 'pronom'
#     details : 'DROID_SignatureFile_V120.xml; container-signature-20240715.xml'
#   - name    : 'tika'
#     details : 'tika-mimetypes.xml (3.1.0, 2025-01-28)'
#   - name    : 'freedesktop.org'
#     details : 'freedesktop.org.xml (2.4, 2023-11-12)'
#   - name    : 'loc'
#     details : 'fddXML.zip (2025-02-26, DROID_SignatureFile_V120.xml, container-signature-20240715.xml)'
#   - name    : 'wikidata'
#     details : 'wikidata-definitions-4.0.0 (2025-03-01)'
# 2025-10-24 17:00:46 :: sf :: sf.go:539: [FATAL] file access error for README.md: lstat README.md: no such file or directory

# %%
# !sf -json -sig deluxe.sig README.md | python -m json.tool
# Out:
# 2025-10-24 17:00:47 :: sf :: sf.go:539: [FATAL] file access error for README.md: lstat README.md: no such file or directory
# {
#     "siegfried": "1.11.2",
#     "scandate": "2025-10-24T17:00:47Z",
#     "signature": "deluxe.sig",
#     "created": "2025-03-01T15:28:39+11:00",
#     "identifiers": [
#         {
#             "name": "pronom",
#             "details": "DROID_SignatureFile_V120.xml; container-signature-20240715.xml"
#         },
#         {
#             "name": "tika",
#             "details": "tika-mimetypes.xml (3.1.0, 2025-01-28)"
#         },
#         {
#             "name": "freedesktop.org",
#             "details": "freedesktop.org.xml (2.4, 2023-11-12)"
#         },
#         {
#             "name": "loc",
#             "details": "fddXML.zip (2025-02-26, DROID_SignatureFile_V120.xml, container-signature-20240715.xml)"
#         },
#         {
#             "name": "wikidata",
#             "details": "wikidata-definitions-4.0.0 (2025-03-01)"
#         }
#     ],
#     "files": []
# }

# %%
# !ls -ld /usr/share/siegfried/*
# Out:
# -rw-r--r-- 1 1001 118 3585703 Mar  1  2025 /usr/share/siegfried/DROID_SignatureFile_V120.xml
# -rw-r--r-- 1 1001 118     195 Mar  1  2025 /usr/share/siegfried/Install.txt
# -rw-r--r-- 1 1001 118  221374 Mar  1  2025 /usr/share/siegfried/archivematica.sig
# -rw-r--r-- 1 1001 118  309050 Mar  1  2025 /usr/share/siegfried/container-signature-20240715.xml
# drwxr-xr-x 2 1001 118    4096 Aug 11 13:44 /usr/share/siegfried/custom
# -rw-r--r-- 1 1001 118  218647 Mar  1  2025 /usr/share/siegfried/default.sig
# -rw-r--r-- 1 1001 118 2238868 Mar  1  2025 /usr/share/siegfried/deluxe.sig
# -rw-r--r-- 1 1001 118 3403337 Mar  1  2025 /usr/share/siegfried/fddXML.zip
# -rw-r--r-- 1 1001 118  313559 Mar  1  2025 /usr/share/siegfried/freedesktop.org.xml
# -rw-r--r-- 1 1001 118   78770 Mar  1  2025 /usr/share/siegfried/freedesktop.sig
# -rw-r--r-- 1 1001 118   42637 Mar  1  2025 /usr/share/siegfried/loc.sig
# -rw-r--r-- 1 1001 118     123 Mar  1  2025 /usr/share/siegfried/mime-info.json
# drwxr-xr-x 2 1001 118   69632 Aug 11 13:44 /usr/share/siegfried/pronom
# -rw-r--r-- 1 1001 118 1167410 Mar  1  2025 /usr/share/siegfried/release-notes.xml
# drwxr-xr-x 2 1001 118    4096 Aug 11 13:44 /usr/share/siegfried/sets
# -rw-r--r-- 1 1001 118  416648 Mar  1  2025 /usr/share/siegfried/tika-mimetypes.xml
# -rw-r--r-- 1 1001 118  119690 Mar  1  2025 /usr/share/siegfried/tika.sig
# drwxr-xr-x 2 1001 118    4096 Aug 11 13:44 /usr/share/siegfried/wikidata
# -rw-r--r-- 1 1001 118 1813203 Mar  1  2025 /usr/share/siegfried/wikidata.sig

# %%
# !sh ~/droid/droid.sh -Nr test-files/lorem-ipsum.txt -q -Ns /usr/share/siegfried/DROID_SignatureFile_V94.xml -Nc /usr/share/siegfried/container-signature-20180917.xml
# Out:
# sh: 0: cannot open /home/jovyan/droid/droid.sh: No such file

# %%
# !sh ~/droid/droid.sh -h
# Out:
# sh: 0: cannot open /home/jovyan/droid/droid.sh: No such file

# %%
# !java -jar tika-app.jar --help
# Out:
# Error: Unable to access jarfile tika-app.jar
